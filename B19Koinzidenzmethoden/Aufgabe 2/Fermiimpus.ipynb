# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import scipy.integrate as integrate

# %%
#Daten einlesen
with open('Messung2,1mm') as data:
    energie = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung2,1mm') as data:
    count21 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung2,4mm') as data:
    energie24 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung2,4mm') as data:
    count24 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung2,7mm') as data:
    energie27 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung2,7mm') as data:
    count27 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung3,0mm') as data:
    energie30 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung3,0mm') as data:
    count30 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung3,3mm') as data:
    energie33 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung3,3mm') as data:
    count33 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung3,6mm') as data:
    energie36 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung3,6mm') as data:
    count36 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung3,9mm') as data:
    energie39 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung3,9mm') as data:
    count39 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung4,2mm') as data:
    energie42 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung4,2mm') as data:
    count42 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung4,5mm') as data:
    energie45 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung4,5mm') as data:
    count45 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung4,8mm') as data:
    energie48 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung4,8mm') as data:
    count48 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung5,1mm') as data:
    energie51 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung5,1mm') as data:
    count51 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung5,4mm') as data:
    energie54 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung5,4mm') as data:
    count54 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung5,7mm') as data:
    energie57 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung5,7mm') as data:
    count57 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung6,0mm') as data:
    energie60 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung6,0mm') as data:
    count60 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung6,3mm') as data:
    energie63 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung6,3mm') as data:
    count63 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung6,6mm') as data:
    energie66 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung6,6mm') as data:
    count66 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

with open('Messung6,9mm') as data:
    energie69 = 151.3 * np.loadtxt((line.replace(',', '.') for line in data), usecols= 0, delimiter=";")
with open('Messung6,9mm') as data:
    count69 = np.loadtxt((line.replace(',', '.') for line in data), usecols= 1, delimiter=";")

# %%
count = count21 + count24 + count27 + count30 + count33 + count36 + count39 + count42 + count45 + count48 + count51 + count54 + count57+ count60 + count63 + count66 + count69

# %%
parameters = {'xtick.labelsize': 20, 'ytick.labelsize': 20}
plt.rcParams.update(parameters)

fig, ax = plt.subplots(figsize=(12,6))

#Name for axis
ax.set_xlabel('Energy [keV]', fontsize=20)
ax.set_ylabel('Count of events', fontsize=20)
#Plot der aufsummierten Events
ax.plot(energie[6:], count[6:],'o',markersize=3, color = "lightblue",label = "Plot der aufsummierten Events")

#Integrationsgrenzen des koinzidenten Peaks
print('Abgezählt aus Count: 110-146')
# Out:
# Abgezählt aus Count: 110-146

# %%
#Summation der Ns
N21 = sum(count21[110:146])
N24 = sum(count24[110:146])
N27 = sum(count27[110:146])
N30 = sum(count30[110:146])
N33 = sum(count33[110:146])
N36 = sum(count36[110:146])
N39 = sum(count39[110:146])
N42 = sum(count42[110:146])
N45 = sum(count45[110:146])
N48 = sum(count48[110:146])
N51 = sum(count51[110:146])
N54 = sum(count54[110:146])
N57 = sum(count57[110:146])
N60 = sum(count60[110:146])
N63 = sum(count63[110:146])
N66 = sum(count66[110:146])
N69 = sum(count69[110:146])

Nsums = [N21,N24,N27,N30,N33,N36,N39,N42,N45,N48,N51,N54,N57,N60,N63,N66,N69]
deltaX = np.array([2.1,2.4,2.7,3.0,3.3,3.6,3.9,4.2,4.5,4.8,5.1,5.4,5.7,6.0,6.3,6.6,6.9])

# %%
#Methoden Parabelfit für Mittelwerte
def parabola(x, a, b, c):
    return a*x**2 + b*x + c

def parabola_fit(x, y):
    # mean = sum(x * y) / sum(y)
    # sigma = np.sqrt(sum(y * (x - mean) ** 2) / sum(y))
    popt, pcov = curve_fit(parabola, x, y)#, p0=[min(y), max(y), mean, sigma])
    return popt[0], popt[1], popt[2], pcov[2,2]

def midnightformulaplus(a,b,c):
    return (-b+np.sqrt(b**2-4*a*c))/(2*a)

def midnightformulaminus(a,b,c):
    return (-b-np.sqrt(b**2-4*a*c))/(2*a)

#Fit
afit, bfit, cfit, fehlermü= parabola_fit(deltaX, Nsums)
print('MW:',round(afit,3), '$\pm$', np.sqrt(fehlermü))

NSminus = midnightformulaminus(afit,bfit,cfit)
NSplus = midnightformulaplus(afit,bfit,cfit)
# NSfehler = midnightformulaplus(afit,bfit,cfit+np.sqrt(parabola(NSplus, afit,bfit,cfit)))
# print("NSFehler:",NSfehler)
print(NSminus)
print(NSplus)

maxdeltax = (NSminus-NSplus)/2
print(maxdeltax)
l = 0.7#m
py = 511000

pF = (maxdeltax*10**(-3)*511000)/l
print("pF=",pF)

Ef = (pF**2)/(2*511000)
print("Ef=",Ef)
# Out:
# MW: -10.509 $\pm$ 35.986097668907156
# 6.8760730900754465
# 2.262306613667778
# 2.3068832382038345
# pF= 1684.024763888799
# Ef= 2.7748917860966005

# %%
fig, ax = plt.subplots(figsize=(12,6))

#Name for axis
ax.set_xlabel('$\Delta x$ [mm]', fontsize=20)
ax.set_ylabel('Count of events', fontsize=20)
#Plot der aufsummierten Events

ax.plot(deltaX, Nsums,'o',markersize=3, color = "lightblue",label = "Plot der aufsummierten Events")
ax.plot(deltaX, parabola(deltaX, afit,bfit,cfit), color = "grey", label="Parabelfit an Integrale")

plt.errorbar(deltaX,parabola(deltaX, afit,bfit,cfit),yerr = 2*np.sqrt(parabola(deltaX, afit,bfit,cfit)),color="grey",capsize=8)

fig.savefig('AnzahlUberAuslenkung.png', dpi=200)
ax.legend(fontsize=15)
# Out:
# /var/folders/0g/9d0z4cfj52j9nl4gwv1kyx9w0000gn/T/ipykernel_1883/3344617278.py:11: RuntimeWarning: invalid value encountered in sqrt
#   plt.errorbar(deltaX,parabola(deltaX, afit,bfit,cfit),yerr = 2*np.sqrt(parabola(deltaX, afit,bfit,cfit)),color="grey",capsize=8)
